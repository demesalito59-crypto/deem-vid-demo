# %% [markdown]
# <a href="https://colab.research.google.com/github/demesalito59-crypto/deem-vid-demo/blob/main/practice_arena1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
for x in range(22):
  print(f"the value is {x}")
# Out:
# the value is 0
# the value is 1
# the value is 2
# the value is 3
# the value is 4
# the value is 5
# the value is 6
# the value is 7
# the value is 8
# the value is 9
# the value is 10
# the value is 11
# the value is 12
# the value is 13
# the value is 14
# the value is 15
# the value is 16
# the value is 17
# the value is 18
# the value is 19
# the value is 20
# the value is 21
